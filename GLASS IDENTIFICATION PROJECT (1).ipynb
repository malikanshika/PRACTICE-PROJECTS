# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing dataset

# %%
df=pd.read_csv("glass[1].csv")

# %%
df
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.00    1
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.00    1
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.00    1
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.00    1
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00    0.26    1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...     ...  ...
# 208  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.00    7
# 209  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.00    7
# 210  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.00    7
# 211  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.00    7
# 212  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.00    7
#
# [213 rows x 11 columns]

# %%
df.columns=['ID no','RI','Na','Mg','AI','Si','K','Ca','Ba','Fe','Type']
print(df)
# Out:
#      ID no       RI     Na    Mg    AI     Si     K    Ca    Ba    Fe  Type
# 0        2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00     1
# 1        3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00     1
# 2        4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00     1
# 3        5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00     1
# 4        6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26     1
# ..     ...      ...    ...   ...   ...    ...   ...   ...   ...   ...   ...
# 208    210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.00     7
# 209    211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.00     7
# 210    212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.00     7
# 211    213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.00     7
# 212    214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.00     7
#
# [213 rows x 11 columns]

# %%
df=pd.read_csv("glass[1].csv",names=df.columns)

# %%
df
# Out:
#      ID no       RI     Na    Mg    AI     Si     K    Ca    Ba   Fe  Type
# 0        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1        2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2        3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3        4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4        5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..     ...      ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209    210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210    211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211    212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212    213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213    214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 11 columns]

# %%
df=df.drop(columns="ID no")

# %%
df
# Out:
#           RI     Na    Mg    AI     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   AI      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
df.head()
# Out:
#         RI     Na    Mg    AI     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
df.tail()
# Out:
#           RI     Na   Mg    AI     Si     K    Ca    Ba   Fe  Type
# 209  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0     7

# %%
df.sample()
# Out:
#           RI     Na   Mg   AI     Si    K    Ca    Ba   Fe  Type
# 205  1.51732  14.95  0.0  1.8  72.99  0.0  8.61  1.55  0.0     7

# %% [markdown]
# # EDA

# %%
df.shape
# Out:
# (214, 10)

# %%
df.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'AI', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
df.columns.tolist()
# Out:
# ['RI', 'Na', 'Mg', 'AI', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type']

# %%
df.dtypes
# Out:
# RI      float64
# Na      float64
# Mg      float64
# AI      float64
# Si      float64
# K       float64
# Ca      float64
# Ba      float64
# Fe      float64
# Type      int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# AI      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
df.describe()
# Out:
#                RI          Na          Mg          AI          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
sns.heatmap(df.isnull(),cmap="cool_r")
# Out:
# <Axes: >

# %%
df['Type'].unique()
# Out:
# array([1, 2, 3, 5, 6, 7], dtype=int64)

# %%
df['Type'].nunique()
# Out:
# 6

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# Univariate analysis

# %%
ax=sns.countplot(x="Type",data=df)

# %%
ax=sns.countplot(x="RI",data=df)

# %%
ax=sns.countplot(x="Na",data=df)

# %%
plt.hist(df['RI'],bins=[0,0.5,1,1.5,2,2.5])
plt.title('RI histogram')
plt.xlabel("RI")
plt.ylabel("frequency")
plt.show()

# %%
plt.hist(df['Na'],bins=[0,5,10,15,20,25])
plt.title('Na histogram')
plt.xlabel("Na")
plt.ylabel("frequency")
plt.show()

# %%
plt.hist(df['Mg'],bins=[0,1,1.5,2,2.5,3,3.5,4,4.5,5])
plt.title('Mg histogram')
plt.xlabel("Mg")
plt.ylabel("frequency")
plt.show()

# %%
plt.hist(df['AI'],bins=[0,0.5,1,1.5,2,2.5,3,3.5,4,4.5])
plt.title('AI histogram')
plt.xlabel("AI")
plt.ylabel("frequency")
plt.show()

# %%
plt.hist(df['Si'],bins=[20,40,60,80,100])
plt.title('Si histogram')
plt.xlabel("Si")
plt.ylabel("frequency")
plt.show()

# %%
plt.hist(df['K'],bins=[0,5,10,15,20])
plt.title('k histogram')
plt.xlabel("k")
plt.ylabel("frequency")
plt.show()

# %%
plt.hist(df['Ca'],bins=[0,5,10,15,20,25])
plt.title('Ca histogram')
plt.xlabel("Ca")
plt.ylabel("frequency")
plt.show()

# %%
plt.hist(df['Ba'],bins=[0,5,10,])
plt.title('Ba histogram')
plt.xlabel("Ba")
plt.ylabel("frequency")
plt.show()

# %%
plt.hist(df['Fe'],bins=[0,5,10,15])
plt.title('Fe histogram')
plt.xlabel("Fe")
plt.ylabel("frequency")
plt.show()

# %%
plt.boxplot(df['RI'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x207907c4550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x207907c4a90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x207907c42b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x207907c4fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x207907c5270>],
#  'means': []}

# %%
plt.boxplot(df['Na'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x207913d35b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x207913d3af0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20790eb9ff0>],
#  'medians': [<matplotlib.lines.Line2D at 0x20791400070>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20791400310>],
#  'means': []}

# %%
plt.boxplot(df['Mg'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2079145cd60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2079145d2a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2079145cac0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2079145d7e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2079145da80>],
#  'means': []}

# %%
plt.boxplot(df['AI'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20791051de0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20791052320>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20791051b40>],
#  'medians': [<matplotlib.lines.Line2D at 0x20791052860>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20791052b00>],
#  'means': []}

# %%
plt.boxplot(df['Si'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x207910a7970>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x207910a7eb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x207910a76d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x207910e8430>],
#  'fliers': [<matplotlib.lines.Line2D at 0x207910e86d0>],
#  'means': []}

# %%
plt.boxplot(df['K'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2079112d240>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2079112d600>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2079112cfa0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2079112db40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2079112dde0>],
#  'means': []}

# %%
plt.boxplot(df['Ca'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x207905ac190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x207905afcd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x207905af640>],
#  'medians': [<matplotlib.lines.Line2D at 0x207905aefb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x207905ac0a0>],
#  'means': []}

# %%
plt.boxplot(df['Ba'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x207908adf60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x207908ae440>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x207908adcc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x207908ae8c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x207908aeb60>],
#  'means': []}

# %%
plt.boxplot(df['Fe'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20790834310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20790834af0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x207908348b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x207d56643a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x207d5664640>],
#  'means': []}

# %%
sns.pairplot(df,kind='reg',height=1.5)

# %%
plt.scatter(df['RI'],df['Na'])

# %%
plt.scatter(df['Mg'],df['AI'])

# %%
plt.scatter(df['Si'],df['K'])

# %%
plt.scatter(df['Ca'],df['Ba'])

# %%
df=df.corr()

# %%
df
# Out:
#             RI        Na        Mg        AI        Si         K        Ca  \
# RI    1.000000 -0.191885 -0.122274 -0.407326 -0.542052 -0.289833  0.810403
# Na   -0.191885  1.000000 -0.273732  0.156794 -0.069809 -0.266087 -0.275442
# Mg   -0.122274 -0.273732  1.000000 -0.481799 -0.165927  0.005396 -0.443750
# AI   -0.407326  0.156794 -0.481799  1.000000 -0.005524  0.325958 -0.259592
# Si   -0.542052 -0.069809 -0.165927 -0.005524  1.000000 -0.193331 -0.208732
# K    -0.289833 -0.266087  0.005396  0.325958 -0.193331  1.000000 -0.317836
# Ca    0.810403 -0.275442 -0.443750 -0.259592 -0.208732 -0.317836  1.000000
# Ba   -0.000386  0.326603 -0.492262  0.479404 -0.102151 -0.042618 -0.112841
# Fe    0.143010 -0.241346  0.083060 -0.074402 -0.094201 -0.007719  0.124968
# Type -0.164237  0.502898 -0.744993  0.598829  0.151565 -0.010054  0.000952
#
#             Ba        Fe      Type
# RI   -0.000386  0.143010 -0.164237
# Na    0.326603 -0.241346  0.502898
# Mg   -0.492262  0.083060 -0.744993
# ...

# %%
sns.heatmap(df,annot=True)
# Out:
# <Axes: >

# %%
from scipy.stats import skew

# %%
df.describe()
# Out:
#               RI         Na         Mg         AI         Si          K  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.023542   0.066799  -0.163628   0.133234  -0.023016   0.020388
# std     0.504881   0.429610   0.481084   0.472904   0.400581   0.394025
# min    -0.542052  -0.275442  -0.744993  -0.481799  -0.542052  -0.317836
# 25%    -0.265346  -0.259901  -0.472286  -0.213295  -0.186480  -0.247898
# 50%    -0.143256  -0.130847  -0.219829   0.075635  -0.098176  -0.026336
# 75%     0.107161   0.284151  -0.026522   0.441043  -0.021595   0.002117
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#               Ca         Ba         Fe       Type
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.031813   0.157222   0.068640   0.172184
# std     0.489869   0.433445   0.350787   0.504023
# min    -0.443750  -0.492262  -0.241346  -0.744993
# 25%    -0.271480  -0.091286  -0.089251  -0.125692
# ...

# %%
df.skew()
# Out:
# RI      1.196272
# Na      1.310773
# Mg      1.631580
# AI      0.443788
# Si      1.989855
# K       1.967245
# Ca      1.369731
# Ba      0.642705
# Fe      2.419613
# Type   -0.131231
# dtype: float64

# %%
df=np.cbrt(df)

# %%
df
# Out:
#             RI        Na        Mg        AI        Si         K        Ca  \
# RI    1.000000 -0.576785 -0.496339 -0.741277 -0.815356 -0.661783  0.932324
# Na   -0.576785  1.000000 -0.649295  0.539233 -0.411753 -0.643192 -0.650644
# Mg   -0.496339 -0.649295  1.000000 -0.783950 -0.549506  0.175394 -0.762745
# AI   -0.741277  0.539233 -0.783950  1.000000 -0.176771  0.688210 -0.637916
# Si   -0.815356 -0.411753 -0.549506 -0.176771  1.000000 -0.578230 -0.593194
# K    -0.661783 -0.643192  0.175394  0.688210 -0.578230  1.000000 -0.682445
# Ca    0.932324 -0.650644 -0.762745 -0.637916 -0.593194 -0.682445  1.000000
# Ba   -0.072812  0.688663 -0.789585  0.782649 -0.467464 -0.349299 -0.483232
# Fe    0.522944 -0.622606  0.436311 -0.420593 -0.455007 -0.197631  0.499958
# Type -0.547634  0.795231 -0.906534  0.842884  0.533171 -0.215834  0.098381
#
#             Ba        Fe      Type
# RI   -0.072812  0.522944 -0.547634
# Na    0.688663 -0.622606  0.795231
# Mg   -0.789585  0.436311 -0.906534
# ...

# %%
df.skew()
# Out:
# RI      0.881177
# Na      0.542591
# Mg      1.277321
# AI     -0.085761
# Si      1.598688
# K       1.086502
# Ca      0.820482
# Ba      0.295593
# Fe      0.624279
# Type   -0.332053
# dtype: float64

# %%
sns.distplot(df,color='m',kde_kws={"shade":True})
plt.show()

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
#             RI        Na        Mg        AI        Si         K        Ca  \
# RI    1.714166  0.779112  0.268195  1.234434  1.041572  0.918250  1.593305
# Na    0.645036  1.566815  0.518766  0.624073  0.296142  0.885122  0.785465
# Mg    0.524671  0.886991  2.183095  1.296368  0.550563  0.573570  0.953922
# AI    0.891151  0.881289  0.739358  1.292821  0.137856  1.487388  0.766338
# Si    1.001988  0.533578  0.355292  0.415120  2.311281  0.769360  0.699132
# K     0.772211  0.877912  0.832232  0.840295  0.603615  2.042988  0.833253
# Ca    1.612909  0.888999  0.704620  1.084418  0.631252  0.955068  1.695003
# Ba    0.109014  1.103610  0.748588  0.977363  0.399037  0.361415  0.533890
# Fe    1.000390  0.847284  1.259665  0.768999  0.376030  0.091147  0.943576
# Type  0.601420  1.262161  0.940173  1.064786  1.449076  0.123584  0.340116
#
#             Ba        Fe      Type
# RI    0.231833  0.990980  1.095809
# Na    0.960933  1.100496  0.910498
# Mg    1.354579  0.832812  1.632022
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
X=df.drop(columns='Type',axis=1)
Y=df['Type']

# %%
X
# Out:
#           RI     Na    Mg    AI     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %%
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: Type, Length: 214, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
X_train.head()
# Out:
#           RI     Na    Mg    AI     Si     K     Ca    Ba   Fe
# 2    1.51618  13.53  3.55  1.54  72.99  0.39   7.78  0.00  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00   8.62  1.67  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57   8.22  0.00  0.0
# 164  1.51915  12.73  1.85  1.86  72.69  0.60  10.09  0.00  0.0
# 14   1.51763  12.61  3.59  1.31  73.29  0.58   8.50  0.00  0.0

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (214, 9) (171, 9) (43, 9)

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import tree
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier,ExtraTreesClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
# Support Vector Machines
svc = SVC()
svc.fit(X_train,Y_train)
y_pred = svc.predict(X_test)
sc1 = metrics.accuracy_score(y_pred,Y_test)
print(sc1)
# Out:
# 0.27906976744186046

# %%
# Gradient Boost Classifier
gbmMod = GradientBoostingClassifier(max_depth = 3, n_estimators = 100, learning_rate = 0.05, random_state = 1)
gbmMod.fit(X_train,Y_train)
y_pred = gbmMod.predict(X_test)
sc2 = metrics.accuracy_score(y_pred,Y_test)
print(sc2)
# Out:
# 0.7441860465116279

# %%
# Decision Tree
DecTree = tree.DecisionTreeClassifier()
DecTree.fit(X_train, Y_train)
y_pred = DecTree.predict(X_test)
sc3 = metrics.accuracy_score(y_pred,Y_test)
print(sc3)
# Out:
# 0.6046511627906976

# %%
# Random Forest
RandFor = RandomForestClassifier(max_depth = 3, min_samples_split=2, n_estimators = 100, random_state = 1)
RandFor.fit(X_train, Y_train)
y_pred = RandFor.predict(X_test)
sc4 = metrics.accuracy_score(y_pred,Y_test)
print(sc4)
# Out:
# 0.6511627906976745

# %%
regressor=LinearRegression()
regressor.fit(X_train,Y_train)
training_data_prediction1=regressor.predict(X_train)
sc5=metrics.r2_score(Y_train,training_data_prediction)
print('R squared value:',sc5)
# Out:
# R squared value: 0.751646707904961

# %%
ET=ExtraTreesClassifier()
ET.fit(X_train,Y_train)
training_data_prediction=ET.predict(X_test)
sc6=metrics.accuracy_score(Y_test,training_data_prediction)

print(sc6)
# Out:
# 0.7906976744186046

# %%
pd.DataFrame([['Support Vector Machine',sc1],['Gradient Boost',sc2],
                             ['Decision Tree',sc3],['Random Forest',sc4],['LinearRegression',sc5],['ExtraTreesClassifier',sc6]],
                                 columns=['Model','Accuracy'])
# Out:
#                     Model  Accuracy
# 0  Support Vector Machine  0.279070
# 1          Gradient Boost  0.744186
# 2           Decision Tree  0.604651
# 3           Random Forest  0.651163
# 4        LinearRegression  0.751647
# 5    ExtraTreesClassifier  0.790698

# %% [markdown]
# # CORRELATION

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(RandFor,X,Y)
print(score)
print(score.mean())
print("Difference between accuracy score and cross validation score is -",accuracy_score(Y_test,y_pred)-score.mean())
# Out:
# [0.55813953 0.72093023 0.53488372 0.55813953 0.66666667]
# 0.6077519379844961
# Difference between accuracy score and cross validation score is - 0.04341085271317835

# %%
score=cross_val_score(ET,X,Y)
print(score)
print(score.mean())
print("Difference between accuracy score and cross validation score is -",accuracy_score(Y_test,training_data_prediction)-score.mean())
# Out:
# [0.65116279 0.76744186 0.55813953 0.65116279 0.73809524]
# 0.6732004429678848
# Difference between accuracy score and cross validation score is - 0.11749723145071977

# %%
score=cross_val_score(regressor,X,Y)
print(score)
print(score.mean())
print("Difference between accuracy score and cross validation score is -",accuracy_score(Y_test,training_data_prediction1)-score.mean())
# Out:
# [  0.          -1.89275799   0.          -0.71762483 -28.10389498]
# -6.142855558800919
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[403], line 4
#       2 print(score)
#       3 print(score.mean())
# ----> 4 print("Difference between accuracy score and cross validation score is -",accuracy_score(Y_test,training_data_prediction1)-score.mean())
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py:192, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 validate_parameter_constraints(
#     188     parameter_constraints, params, caller_name=func.__qualname__
#     189 )
#     191 try:
# --> 192     return func(*args, **kwargs)
#     193 except InvalidParameterError as e:
#     194     # When the function is just a wrapper around an estimator, we allow
# ...

# %% [markdown]
# # HYPER PARAMETER TUNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
tuned_parameters = [{'criterion': ['gini','entropy'], 'random_state': [10,50,100],
                     'max_depth': [0,10,20],'n_jobs':[-2,-1,1],'n_estimators':[50,100,200,300]}]
grid = GridSearchCV(ExtraTreesClassifier(), tuned_parameters, cv=5)
grid.fit(X_train, Y_train)
print("Best parameters set found on development set:")
print()
print(grid.best_params_)
# Out:
# Best parameters set found on development set:
#
# {'criterion': 'entropy', 'max_depth': 20, 'n_estimators': 100, 'n_jobs': -2, 'random_state': 50}

# %% [markdown]
# # BUILDING THE FINAL MODEL

# %%
final_model=ExtraTreesClassifier(criterion='entropy',max_depth=20,n_estimators=100,n_jobs=-2,random_state=50)
final_model.fit(X_train,Y_train)
pred=final_model.predict(X_test)
acc=accuracy_score(Y_test,pred)
print(acc*100)
# Out:
# 79.06976744186046

# %% [markdown]
# # PLOTTING ROC

# %%
from sklearn import datasets
from sklearn import metrics
from sklearn.metrics import RocCurveDisplay

# %%
from sklearn import metrics

# %%
fpr,tpr,thresholds=metrics.roc_curve(Y_test,pred)
roc_auc=metrics.auc(fpr,tpr)
display=metrics.RocCurveDisplay(fpr=fpr,tpr=tpr,estimator_name=final_model)
display.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[407], line 1
# ----> 1 fpr,tpr,thresholds=metrics.roc_curve(Y_test,pred)
#       2 roc_auc=metrics.auc(fpr,tpr)
#       3 display=metrics.RocCurveDisplay(fpr=fpr,tpr=tpr,estimator_name=final_model)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py:992, in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     904 def roc_curve(
#     905     y_true, y_score, *, pos_label=None, sample_weight=None, drop_intermediate=True
#     906 ):
#     907     """Compute Receiver operating characteristic (ROC).
#     908
#     909     Note: this implementation is restricted to the binary classification task.
#    (...)
#     990     array([1.8 , 0.8 , 0.4 , 0.35, 0.1 ])
#     991     """
# --> 992     fps, tps, thresholds = _binary_clf_curve(
# ...

# %%
mat = confusion_matrix(Y_test, y_pred)
plt.subplots(figsize=(12,8))
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label')
# Out:
# Text(274.25, 0.5, 'predicted label')

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.76      0.72      0.74        18
#            2       0.45      0.75      0.56        12
#            3       0.00      0.00      0.00         3
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         2
#            7       1.00      0.86      0.92         7
#
#     accuracy                           0.65        43
#    macro avg       0.37      0.39      0.37        43
# weighted avg       0.61      0.65      0.62        43

# %% [markdown]
# # SAVIND THE MODEL

# %%
import joblib
joblib.dump(final_model,'glass_identification_project.pkl')
# Out:
# ['glass_identification_project.pkl']

# %%
model=joblib.load('glass_identification_project.pkl')


prediction=model.predict(X_test)
prediction
# Out:
# array([1, 2, 7, 1, 1, 2, 1, 7, 2, 1, 2, 2, 6, 1, 2, 3, 2, 2, 1, 7, 5, 2,
#        5, 1, 7, 7, 1, 3, 1, 1, 2, 7, 2, 2, 1, 1, 2, 1, 2, 1, 1, 2, 2],
#       dtype=int64)
